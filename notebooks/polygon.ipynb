// %%
const POLYGON_API_KEY = "xwT5y_ojBtjcbfpenK63mL04EttLNw34";
const POLYGON_BASE_URL = "https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/day/2023-01-09/2023-02-10"

// %%
import { restClient } from "npm:@polygon.io/client-js";

// %%
const client = restClient(POLYGON_API_KEY)

// %%
client.stocks.aggregates("QQQM", 1, "day", "2023-01-01", "2023-04-14").then((data) => {
	console.log(data);
}).catch(e => {
	console.error('An error happened:', e);
});
// Out:
// Promise { <pending> }
// {
//   ticker: "QQQM",
//   queryCount: 71,
//   resultsCount: 71,
//   adjusted: true,
//   results: [
//     {
//       v: 1514139,
//       vw: 108.814,
//       o: 110.5,
//       c: 108.75,
//       h: 111.11,
//       l: 107.85,
//       t: 1672722000000,
//       n: 13316
//     },
//     {
//       v: 750106,
//       vw: 109.1744,
//       o: 109.68,
//       c: 109.31,
//       h: 110.01,
//       l: 108,
//       t: 1672808400000,
//       n: 7168
//     },
//     {
//       v: 848878,
//       vw: 107.9267,
//       o: 108.57,
//       c: 107.7,
//       h: 108.66,
//       l: 107.48,
//       t: 1672894800000,
//       n: 7353
//     },
//     {
//       v: 1068796,
//       vw: 108.6951,
//       o: 108.36,
//       c: 110.54,
//       h: 111.01,
//       l: 107.14,
//       t: 1672981200000,
//       n: 8398
//     },
//     {
//       v: 1815533,
//       vw: 112.5211,
//       o: 111.49,
//       c: 111.34,
//       h: 113.24,
// ...

// %%
client.reference.tickerDetails("AAPL").then((data) => {
	console.log(data);
}).catch(e => {
	console.error('An error happened:', e);
});
// Out:
// Promise { <pending> }
// {
//   request_id: "c92c2b2d93b48101868da6c45266158d",
//   results: {
//     ticker: "AAPL",
//     name: "Apple Inc.",
//     market: "stocks",
//     locale: "us",
//     primary_exchange: "XNAS",
//     type: "CS",
//     active: true,
//     currency_name: "usd",
//     cik: "0000320193",
//     composite_figi: "BBG000B9XRY4",
//     share_class_figi: "BBG001S5N8V8",
//     market_cap: 3458410262520,
//     phone_number: "(408) 996-1010",
//     address: {
//       address1: "ONE APPLE PARK WAY",
//       city: "CUPERTINO",
//       state: "CA",
//       postal_code: "95014"
//     },
// ...

// %%
client.reference.tickerNews("AAPL")
  .then((data) => {
    console.log(data);
  })
  .catch(e => {
    console.error("An error happened:", e);
  })
// Out:
// Promise { <pending> }
// {
//   results: [
//     {
//       id: "8321bc469e19f19a00e79bbf46265b9dcb4811257afcf8a6a8e3bb9b0c5ee56b",
//       publisher: {
//         name: "GlobeNewswire Inc.",
//         homepage_url: "https://www.globenewswire.com",
//         logo_url: "https://s3.polygon.io/public/assets/news/logos/globenewswire.svg",
//         favicon_url: "https://s3.polygon.io/public/assets/news/favicons/globenewswire.ico"
//       },
//       title: "Quanterix Corporation Announcement: If You Have Suffered Losses in Quanterix Corporation (NASDAQ: QTRX), You Are Encouraged to Contact The Rosen Law Firm About Your Rights",
//       author: "N/A",
//       published_utc: "2025-01-12T21:48:00Z",
//       article_url: "https://www.globenewswire.com/news-release/2025/01/12/3008075/673/en/Quanterix-Corporation-Announcement-If-You-Have-Suffered-Losses-in-Quanterix-Corporation-NASDAQ-QTRX-You-Are-Encouraged-to-Contact-The-Rosen-Law-Firm-About-Your-Rights.html",
// ...

// %%
client.reference.dividends("AAPL").then((data) => {
	console.log(data);
}).catch(e => {
	console.error('An error happened:', e);
});
// Out:
// Promise { <pending> }
// {
//   results: [
//     {
//       cash_amount: 0.51345,
//       currency: "USD",
//       dividend_type: "CD",
//       ex_dividend_date: "2029-12-15",
//       frequency: 4,
//       id: "E5517750748dca0bc3e1e237ccfd6468a93f3d2ab543dfcb8b4fef4ccb7b8e463",
//       pay_date: "2029-12-31",
//       record_date: "2029-12-15",
//       ticker: "GECCH"
//     },
//     {
//       cash_amount: 0.50781,
//       currency: "USD",
//       dividend_type: "CD",
//       ex_dividend_date: "2029-09-15",
//       frequency: 4,
//       id: "E167fa436de76a284f12df82d1b841a78f846a6f9b0e6e4079194281b783feaf2",
//       pay_date: "2029-09-30",
//       record_date: "2029-09-15",
//       ticker: "GECCH"
//     },
//     {
//       cash_amount: 0.50217,
//       currency: "USD",
//       dividend_type: "CD",
//       ex_dividend_date: "2029-06-15",
//       frequency: 4,
//       id: "E9a931a87e4c39dc10271e53ee0bfd4a5370e36b8ba9f552b5879e0f2379faa6e",
// ...
